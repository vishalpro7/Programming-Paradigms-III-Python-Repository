# %% [markdown]
# <a href="https://colab.research.google.com/github/vishalpro7/Programming-Paradigms-III-Python-Repository/blob/main/LEVEL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re
pattern = "cat"
Animal = input("Enter a name:")
if re.match(pattern,Animal):
  print("Valid Input")
else:
  print("Invalid Input")
# Out:
# Enter a name:cat
# Valid Input

# %%
import re
pattern = "cat|dog"
Animal = input("Enter a animal:")
if re.match(pattern,Animal):
  print("Valid Input")
else:
  print("Invalid Input")
# Out:
# Enter a animal:dog
# Valid Input

# %%
import re
pattern = "[0-9]"
Number = input("Enter a number:")
if re.match(pattern,Number):
  print("Valid Input")
else:
  print("Invalid Input")
# Out:
# Enter a number:9
# Invalid Input

# %%
import re
pattern = "[a-z]"
Alpha = input("Enter a word:")
if re.match(pattern,Alpha):
  print("Valid Input")
else:
  print("Invalid Input")
# Out:
# Enter a word:word
# Valid Input

# %%
import re
pattern = "[A-z]"
Alpha = input("Enter a word:")
if re.match(pattern,Alpha):
  print("Valid Input")
else:
  print("Invalid Input")
# Out:
# Enter a word:Vijay
# Valid Input

# %%
import re
pattern = r"\d{4}" # Changed to a raw string to avoid SyntaxWarning
Alpha = input("Enter a word:")
if re.match(pattern,Alpha):
  print("Valid Input")
else:
  print("Invalid Input")
# Out:
# Enter a word:676767
# Valid Input

# %%
import re
pattern = r"\d{2,}" # Changed to a raw string to avoid SyntaxWarning
Alpha = input("Enter a word:")
if re.match(pattern,Alpha):
  print("Valid Input")
else:
  print("Invalid Input")
# Out:
# Enter a word:67
# Valid Input

# %%
import re
pattern = r"\d*" # Changed to a raw string to avoid SyntaxWarning
Alpha = input("Enter a word:")
if re.match(pattern,Alpha):
  print("Valid Input")
else:
  print("Invalid Input")
# Out:
# Enter a word:6776+++
# Valid Input

# %%
import re
pattern = r"[a-z]{3}" # Changed to a raw string to avoid SyntaxWarning
Alpha = input("Enter a word:")
if re.match(pattern,Alpha):
  print("Valid Input")
else:
  print("Invalid Input")
# Out:
# Enter a word:abbas
# Valid Input

# %%
import re
pattern = r"\w{5,10}" # Changed to a raw string to avoid SyntaxWarning
Alpha = input("Enter a word:")
if re.match(pattern,Alpha):
  print("Valid Input")
else:
  print("Invalid Input")
# Out:
# Enter a word:mahas
# Valid Input

# %%
import re
pattern = r"[aeiouAEIOU]" # Changed to a raw string to avoid SyntaxWarning
Alpha = input("Enter a word:")
if re.match(pattern,Alpha):
  print("Valid Input")
else:
  print("Invalid Input")
# Out:
# Enter a word:word
# Invalid Input

# %%
import re
pattern = r"[^aeiouAEIOU\W\d_]"
Alpha = input("Enter a word:")
if re.match(pattern,Alpha):
  print("Valid Input")
else:
  print("Invalid Input")
# Out:
# Enter a word:fgjjvjh
# Valid Input

# %%
import re
pattern = r"^A.*" # Changed to a raw string to avoid SyntaxWarning
Alpha = input("Enter a word:")
if re.match(pattern,Alpha):
  print("Valid Input")
else:
  print("Invalid Input")
# Out:
# Enter a word:Apple
# Valid Input

# %%
import re
pattern = r"^[a-zA-Z0-9._]+@{gmail}+\.[com]{2,}$" # Changed to a raw string to avoid SyntaxWarning
Alpha = input("Enter a word:")
if re.match(pattern,Alpha):
  print("Valid Input")
else:
  print("Invalid Input")
# Out:
# Enter a word:likevenkat6@mailg.com
# Invalid Input

# %%
import re
pattern = r"^[a-zA-Z0-9._]+@{gmail}+\.[com]{2,}$" # Changed to a raw string to avoid SyntaxWarning
Alpha = input("Enter a word:")
if re.match(pattern,Alpha):
  print("Valid Input")
else:
  print("Invalid Input")

# %%
import re
pattern = r"\s+" # Changed to a raw string to avoid SyntaxWarning
Alpha = input("Enter a word:")
if re.match(pattern,Alpha):
  print("Valid Input")
else:
  print("Invalid Input")
# Out:
# Enter a word:
# Invalid Input

# %%
import re
pattern = r"\w+(?:\s+\w+)+" # Changed to a raw string to avoid SyntaxWarning
Alpha = input("Enter a word:")
if re.match(pattern,Alpha):
  print("Valid Input")
else:
  print("Invalid Input")
# Out:
# Enter a word:Hello World
# Valid Input

# %%
import re
pattern = r"\w+" # Changed to a raw string to avoid SyntaxWarning
Alpha = input("Enter a word:")
if re.match(pattern,Alpha):
  print("Valid Input")
else:
  print("Invalid Input")
# Out:
# Enter a word:Word
# Valid Input

# %%
import re
pattern = r"\w+$" # Changed to a raw string to avoid SyntaxWarning
Alpha = input("Enter a word:")
if re.match(pattern,Alpha):
  print("Valid Input")
else:
  print("Invalid Input")
# Out:
# Enter a word:kesari
# Valid Input

# %%
import re
pattern = r"\b\w+\b" # Changed to a raw string to avoid SyntaxWarning
Alpha = input("Enter a word:")
if re.match(pattern,Alpha):
  print("Valid Input")
else:
  print("Invalid Input")
# Out:
# Enter a word:hello
# Valid Input
